# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
from pandas.tools.plotting import scatter_matrix

# Introduction 
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
recent_grads.head()
recent_grads.tail()
recent_grads.describe()
raw_data_count = recent_grads.shape[0]  
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]

# Pandas, Scatter Plots
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')

# Pandas, Histograms
recent_grads['Sample_size'].hist(bins=25, range=(0, 5000))
recent_grads['Median'].hist(bins=25, range=(20000, 80000))
recent_grads['Employed'].hist(bins=25, range=(0, 200000))
recent_grads['Full_time'].hist(bins=25)
recent_grads['ShareWomen'].hist(bins=25)
recent_grads['Unemployment_rate'].hist(bins=25)
recent_grads['Men'].hist(bins=25)
recent_grads['Women'].hist(bins=25)

# Pandas, Scatter Matrix Plot
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))

# Pandas, Bar Plots
recent_grads[:10][-10:]['ShareWomen'].plot.bar(color='red')
recent_grads[:10][-10:]['Unemployment_rate'].plot.bar(color='blue')
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:35: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:36: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %% [markdown]
# ### My Changes
